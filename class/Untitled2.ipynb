# %%
import matplotlib.pyplot as plt
import numpy as np
import skimage
import cv2

# %%
from skimage import data
from skimage import io

# %%
print(data.camera())
# Out:
# [[156 157 160 ... 152 152 152]
#  [156 157 159 ... 152 152 152]
#  [158 157 156 ... 152 152 152]
#  ...
#  [121 123 126 ... 121 113 111]
#  [121 123 126 ... 121 113 111]
#  [121 123 126 ... 121 113 111]]

# %%
image = data.coins()
plt.imshow(image)

# %%
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))

# %%
type(image)

print(image.dtype)
print(image.ndim)
print(image.size)
print(image.shape)
print(image.shape[0])
print(image.shape[1])
# Out:
# uint8
# 2
# 116352
# (303, 384)
# 303
# 384

# %%
image = skimage.color.rgb2gray(image)

for i in range(image.shape[0]):
  for j in range(image.shape[1]):
    image[i][j] = 0;

# %%
plt.imshow(image)

# %%
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))

# %%
hist_image = io.imread("shape.png")
plt.imshow(hist_image)

# %%
plt.imshow(cv2.cvtColor(hist_image, cv2.COLOR_BGR2RGB))

# %%
hist_image_gray = skimage.color.rgb2gray(hist_image)

# %%
image_noised = skimage.util.random_noise(image, mode="gaussian")

plt.imshow(skimage.util.random_noise(image, mode="salt",  seed=None, clip=True));
